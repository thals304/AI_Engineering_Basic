# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 다운로드
# !wget –no-check-certificate 'https://docs.google.com/uc?export=download&id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0' -O kaggle-kakr-housing-data.zip
# Out:
# --2024-01-19 13:54:28--  http://xn--no-check-certificate-2t2l/
# Resolving xn--no-check-certificate-2t2l (xn--no-check-certificate-2t2l)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--no-check-certificate-2t2l’
# --2024-01-19 13:54:28--  https://docs.google.com/uc?export=download&id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0
# Resolving docs.google.com (docs.google.com)... 74.125.197.113, 74.125.197.102, 74.125.197.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0&export=download [following]
# --2024-01-19 13:54:28--  https://drive.usercontent.google.com/download?id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.253.117.132, 2607:f8b0:400e:c09::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.253.117.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 693719 (677K) [application/octet-stream]
# Saving to: ‘kaggle-kakr-housing-data.zip’
#
# kaggle-kakr-housing 100%[===================>] 677.46K  --.-KB/s    in 0.004s
#
# 2024-01-19 13:54:28 (188 MB/s) - ‘kaggle-kakr-housing-data.zip’ saved [693719/693719]
#
# FINISHED --2024-01-19 13:54:28--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 677K in 0.004s (188 MB/s)

# %%
# 다운로드 받은 zip파일 압축풀기
# !unzip -qq ./kaggle-kakr-housing-data.zip

# %%
train_data_path = './data/train.csv'
test_data_path = './data/test.csv'

data = pd.read_csv(train_data_path)
sub = pd.read_csv(test_data_path)
print('train data dim : {}'.format(data.shape))
print('sub data dim : {}'.format(sub.shape))
# Out:
# train data dim : (15035, 21)
# sub data dim : (6468, 20)

# %%
## 코드시작 ##
# 미션 1 코드 작성 : 캐글에 가입하고, 프로필명 공유하기

print('somin1004')  # '...' 에 프로필명을 채워주세요

## 코드종료 ##
# Out:
# somin1004

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 다운로드
# !wget –no-check-certificate 'https://docs.google.com/uc?export=download&id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0' -O kaggle-kakr-housing-data.zip

# 다운로드 받은 zip파일 압축풀기
# !unzip -qq ./kaggle-kakr-housing-data.zip

train_data_path = './data/train.csv'
test_data_path = './data/test.csv'

data = pd.read_csv(train_data_path)
sub = pd.read_csv(test_data_path)
print('train data dim : {}'.format(data.shape))
print('sub data dim : {}'.format(sub.shape))

# data의 price를 y로 옮기기
y = data['price']

## 코드시작 ##
# 미션 2 코드 작성 : data에서 price 컬럼을 완전히 삭제하기
del data ['price']


## 코드종료 ##

print(data.columns)

train_len = len(data) # 학습데이터의 수
data = pd.concat((data, sub), axis=0) # 학습데이터와 테스트 데이터 합치기

print(len(data)) # 합쳐진 데이터의 수
data.head() # 데이터 확인

data.info()
# Out:
# --2024-01-19 14:00:48--  http://xn--no-check-certificate-2t2l/
# Resolving xn--no-check-certificate-2t2l (xn--no-check-certificate-2t2l)... failed: Name or service not known.
# wget: unable to resolve host address ‘xn--no-check-certificate-2t2l’
# --2024-01-19 14:00:48--  https://docs.google.com/uc?export=download&id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0
# Resolving docs.google.com (docs.google.com)... 74.125.142.138, 74.125.142.113, 74.125.142.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0&export=download [following]
# --2024-01-19 14:00:48--  https://drive.usercontent.google.com/download?id=1IVvuG3SMlarSSGmcliGFjq1fMxZtksE0&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.195.132, 2607:f8b0:400e:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 693719 (677K) [application/octet-stream]
# Saving to: ‘kaggle-kakr-housing-data.zip’
#
# kaggle-kakr-housing 100%[===================>] 677.46K  --.-KB/s    in 0.006s
#
# 2024-01-19 14:00:49 (115 MB/s) - ‘kaggle-kakr-housing-data.zip’ saved [693719/693719]
#
# FINISHED --2024-01-19 14:00:49--
# Total wall clock time: 1.1s
# Downloaded: 1 files, 677K in 0.006s (115 MB/s)
# replace data/sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: train data dim : (15035, 21)
# sub data dim : (6468, 20)
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# 21503
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21503 entries, 0 to 6467
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21503 non-null  int64
#  1   date           21503 non-null  object
#  2   bedrooms       21503 non-null  int64
#  3   bathrooms      21503 non-null  float64
#  4   sqft_living    21503 non-null  int64
#  5   sqft_lot       21503 non-null  int64
#  6   floors         21503 non-null  float64
#  7   waterfront     21503 non-null  int64
#  8   view           21503 non-null  int64
#  9   condition      21503 non-null  int64
#  10  grade          21503 non-null  int64
#  11  sqft_above     21503 non-null  int64
#  12  sqft_basement  21503 non-null  int64
#  13  yr_built       21503 non-null  int64
#  14  yr_renovated   21503 non-null  int64
#  15  zipcode        21503 non-null  int64
#  16  lat            21503 non-null  float64
#  17  long           21503 non-null  float64
#  18  sqft_living15  21503 non-null  int64
#  19  sqft_lot15     21503 non-null  int64
# dtypes: float64(4), int64(15), object(1)
# memory usage: 3.4+ MB

# %%
## 코드시작 ##
# 미션 3-1 코드 작성 : data에 isna와 sum을 적용하여 각 컬럼의 결측치 수를 확인해보세요.

missing = data.isna().sum()
print(missing)


## 코드종료 ##

missing_percentage = missing/data.shape[0]
print(missing_percentage)

data.describe()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64
# id               0.0
# date             0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# grade            0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# zipcode          0.0
# lat              0.0
# long             0.0
# sqft_living15    0.0
# sqft_lot15       0.0
# dtype: float64
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  21503.000000  21503.000000  21503.000000  21503.000000  2.150300e+04
# mean   10751.000000      3.371762      2.116042   2081.441334  1.511715e+04
# std     6207.525755      0.930026      0.770018    918.669624  4.147591e+04
# min        0.000000      0.000000      0.000000    290.000000  5.200000e+02
# 25%     5375.500000      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    10751.000000      3.000000      2.250000   1914.000000  7.616000e+03
# 75%    16126.500000      4.000000      2.500000   2550.000000  1.068600e+04
# max    21502.000000     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21503.000000  21503.000000  21503.000000  21503.000000  21503.000000
# mean       1.495140      0.007580      0.234618      3.409710      7.659164
# std        0.540183      0.086737      0.766453      0.650066      1.174422
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21503.000000   21503.000000  21503.000000  21503.000000  21503.000000
# mean    1789.765986     291.675348   1971.055016     84.741943  98077.897968
# std      828.481664     442.645882     29.372398    402.452836     53.489890
# min      290.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1200.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98117.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21503.000000  21503.000000   21503.000000   21503.000000
# mean      47.560121   -122.213786    1987.242664   12774.529089
# std        0.138615      0.140833     685.579479   27334.995914
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571900   -122.230000    1840.000000    7620.000000
# 75%       47.678100   -122.125000    2370.000000   10085.000000
# max       47.777600   -121.315000    6210.000000  871200.000000
